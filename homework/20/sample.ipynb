# %% [markdown]
# # 動態網頁爬蟲 - API Request
#
# * 了解 API Request 用於動態網頁爬蟲的原理
# * 能夠使用 API Request 撰寫動態網頁爬蟲

# %% [markdown]
# ## 觀察 API 請求資訊

# %% [markdown]
# ![](https://imgur.com/qBmCUxR.jpg)

# %% [markdown]
# ![](https://imgur.com/Xi5kYFX.jpg)

# %%
import requests
import json

r = requests.get('https://fhy.wra.gov.tw/fhy/api/ReservoirInfoApi/DryAreaGetAll')
d = json.loads(r.text)

d
# Out:
# [{'AREA_NO': 'A01',
#   'AREA_NAME': '北區',
#   'Warns': None,
#   'DryView': [{'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-09-16T19:00:00',
#     'NWL_MX': 245.0,
#     'Capacity': 20344.176,
#     'CapacityRate': 100.0,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 20266.07,
#     'StationNo': '10201',
#     'StationName': '石門水庫',
#     'BasinNo': '1140',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-09-16T08:00:00',
#     'NWL_MX': 86.0,
#     'Capacity': 746.9,
#     'CapacityRate': 74.54091816367266,
#     'Status': 5,
#     'Basin_Rain': 6.5,
#     'EffectiveCapacity': 1002.0,
#     'StationNo': '10204',
#     'StationName': '新山水庫',
#     'BasinNo': '1140',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-09-16T19:00:00',
#     'NWL_MX': 170.0,
#     'Capacity': 29675.45,
#     'CapacityRate': 88.4500976140445,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 33550.5,
#     'StationNo': '10205',
#     'StationName': '翡翠水庫',
#     'BasinNo': '1140',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-09-16T19:00:00',
#     'NWL_MX': 150.0,
#     'Capacity': 3168.06,
#     'CapacityRate': 100.0,
#     'Status': 5,
#     'Basin_Rain': 0.3,
#     'EffectiveCapacity': 3147.18,
#     'StationNo': '10405',
#     'StationName': '寶山第二水庫',
#     'BasinNo': '1300',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-09-16T19:00:00',
#     'NWL_MX': 85.0,
#     'Capacity': 2873.368,
#     'CapacityRate': 95.81278718480529,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 2998.94,
#     'StationNo': '10501',
#     'StationName': '永和山水庫',
#     'BasinNo': '105',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-09-16T07:00:00',
#     'NWL_MX': 61.0,
#     'Capacity': 1179.4764,
#     'CapacityRate': 96.51648308665153,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 1222.05,
#     'StationNo': '10601',
#     'StationName': '明德水庫',
#     'BasinNo': '1350',
#     'Basin': None}]},
#  {'AREA_NO': 'A02',
#   'AREA_NAME': '中區',
#   'Warns': None,
#   'DryView': [{'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-09-16T18:00:00',
#     'NWL_MX': 300.0,
#     'Capacity': 11490.12,
#     'CapacityRate': 100.0,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 11446.01,
#     'StationNo': '20101',
#     'StationName': '鯉魚潭水庫',
#     'BasinNo': '1400',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-09-16T08:00:00',
#     'NWL_MX': 1408.0,
#     'Capacity': 16564.54,
#     'CapacityRate': 88.85602403175625,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 18642.0,
#     'StationNo': '20201',
#     'StationName': '德基水庫',
#     'BasinNo': '1420',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-09-16T07:00:00',
#     'NWL_MX': 1005.0,
#     'Capacity': 2637.19,
#     'CapacityRate': 70.40335519764646,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 3752.88,
#     'StationNo': '20501',
#     'StationName': '霧社水庫',
#     'BasinNo': '1510',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-09-16T07:00:00',
#     'NWL_MX': 748.48,
#     'Capacity': 12467.34,
#     'CapacityRate': 97.3552303094714,
#     'Status': 5,
#     'Basin_Rain': 4.0,
#     'EffectiveCapacity': 12806.03,
#     'StationNo': '20502',
#     'StationName': '日月潭水庫',
#     'BasinNo': '1510',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-09-16T19:00:00',
#     'NWL_MX': 214.75,
#     'Capacity': 227.21,
#     'CapacityRate': 35.95606969346901,
#     'Status': 5,
#     'Basin_Rain': 1.6,
#     'EffectiveCapacity': 631.91,
#     'StationNo': '20503',
#     'StationName': '集集攔河堰',
#     'BasinNo': '1510',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-09-16T19:00:00',
#     'NWL_MX': 211.5,
#     'Capacity': 5104.0,
#     'CapacityRate': 100.0,
#     'Status': 5,
#     'Basin_Rain': 67.0,
#     'EffectiveCapacity': 5087.0,
#     'StationNo': '20509',
#     'StationName': '湖山水庫',
#     'BasinNo': '1510',
#     'Basin': None}]},
#  {'AREA_NO': 'A03',
#   'AREA_NAME': '南區',
#   'Warns': None,
#   'DryView': [{'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-09-16T07:00:00',
#     'NWL_MX': 105.0,
#     'Capacity': 2358.39,
#     'CapacityRate': 95.01017222278175,
#     'Status': 5,
#     'Basin_Rain': 3.0,
#     'EffectiveCapacity': 2482.2,
#     'StationNo': '30301',
#     'StationName': '仁義潭水庫',
#     'BasinNo': '1580',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-09-16T08:00:00',
#     'NWL_MX': 109.0,
#     'Capacity': 950.0,
#     'CapacityRate': 80.9578593037624,
#     'Status': 5,
#     'Basin_Rain': 5.7,
#     'EffectiveCapacity': 1173.45,
#     'StationNo': '30401',
#     'StationName': '白河水庫',
#     'BasinNo': '1590',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-09-16T07:00:00',
#     'NWL_MX': 58.18,
#     'Capacity': 7074.0,
#     'CapacityRate': 90.02405222769443,
#     'Status': 5,
#     'Basin_Rain': 5.8,
#     'EffectiveCapacity': 7857.9,
#     'StationNo': '30501',
#     'StationName': '烏山頭水庫',
#     'BasinNo': '1630',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-09-16T19:00:00',
#     'NWL_MX': 230.0,
#     'Capacity': 50291.0,
#     'CapacityRate': 98.69495250804616,
#     'Status': 5,
#     'Basin_Rain': 13.2,
#     'EffectiveCapacity': 50956.0,
#     'StationNo': '30502',
#     'StationName': '曾文水庫',
#     'BasinNo': '1630',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-09-16T07:00:00',
#     'NWL_MX': 180.0,
#     'Capacity': 9138.72,
#     'CapacityRate': 100.0,
#     'Status': 5,
#     'Basin_Rain': 27.6,
#     'EffectiveCapacity': 9097.9,
#     'StationNo': '30503',
#     'StationName': '南化水庫',
#     'BasinNo': '1630',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-09-16T19:00:00',
#     'NWL_MX': 37.0,
#     'Capacity': 617.0,
#     'CapacityRate': 40.43533851980447,
#     'Status': 5,
#     'Basin_Rain': 13.3,
#     'EffectiveCapacity': 1525.9,
#     'StationNo': '30802',
#     'StationName': '阿公店水庫',
#     'BasinNo': '308',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-09-16T19:00:00',
#     'NWL_MX': 142.0,
#     'Capacity': 2224.0,
#     'CapacityRate': 83.8828401130457,
#     'Status': 5,
#     'Basin_Rain': 18.9,
#     'EffectiveCapacity': 2651.317,
#     'StationNo': '31201',
#     'StationName': '牡丹水庫',
#     'BasinNo': '312',
#     'Basin': None}]}]

# %% [markdown]
# ## 作業目標
#
# * 根據範例的教學，去找出 Dcard 中呼叫的 API 當中，有一個跟「取得所有看板」是哪一個？並且利用 Requests 呼叫。
